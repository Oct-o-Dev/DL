# %% [markdown]
# <a href="https://colab.research.google.com/github/Oct-o-Dev/DL/blob/main/IMDB_movie_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

docs = [
    'go india',
    'india india' ,
    'jeetega bhai jeetega india jeetega',
    'bharat mata ki jai',
    'kohli kohli',
    'sachin sachin',
    'dhoni dhoni',
    'modi ji ki jai',
    'inquilab zindabad'
]

# %%
pip install tensorflow

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token='<nothing>')

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'<nothing>': 1,
#  'india': 2,
#  'jeetega': 3,
#  'ki': 4,
#  'jai': 5,
#  'kohli': 6,
#  'sachin': 7,
#  'dhoni': 8,
#  'go': 9,
#  'bhai': 10,
#  'bharat': 11,
#  'mata': 12,
#  'modi': 13,
#  'ji': 14,
#  'inquilab': 15,
#  'zindabad': 16}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('go', 1),
#              ('india', 4),
#              ('jeetega', 3),
#              ('bhai', 1),
#              ('bharat', 1),
#              ('mata', 1),
#              ('ki', 2),
#              ('jai', 2),
#              ('kohli', 2),
#              ('sachin', 2),
#              ('dhoni', 2),
#              ('modi', 1),
#              ('ji', 1),
#              ('inquilab', 1),
#              ('zindabad', 1)])

# %%
tokenizer.document_count
# Out:
# 9

# %%
sequences = tokenizer.texts_to_sequences(docs)

# %%
sequences
# Out:
# [[9, 2],
#  [2, 2],
#  [3, 10, 3, 2, 3],
#  [11, 12, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [13, 14, 4, 5],
#  [15, 16]]

# %%
from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences , padding='post')

# %%
sequences
# Out:
# array([[ 9,  2,  0,  0,  0],
#        [ 2,  2,  0,  0,  0],
#        [ 3, 10,  3,  2,  3],
#        [11, 12,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [13, 14,  4,  5,  0],
#        [15, 16,  0,  0,  0]], dtype=int32)

# %%
from keras.datasets import imdb
from keras import Sequential
from keras.layers import Dense,SimpleRNN , Embedding , Flatten

# %%
(X_train , y_train) , (X_test , y_test) = imdb.load_data(num_words=10000)

# %%
X_train
# Out:
# array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 22665, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 21631, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 31050, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
# ...

# %%
X_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
# ...

# %%
X_train = pad_sequences(list(X_train) , padding='post' , maxlen=50)
X_test = pad_sequences(list(X_test) , padding='post' , maxlen=50)

# %%
X_train.shape
# Out:
# (25000, 50)

# %%
model = Sequential()
model.add(Embedding(10000, 2, input_shape=(50,)))
model.add(SimpleRNN(32 , return_sequences=False))
model.add(Dense(1 , activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:103: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 50, 2)          │        20,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 32)             │         1,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# ...

# %%
model.compile(optimizer='adam' , loss='binary_crossentropy' , metrics=['accuracy'])
hist = model.fit(X_train , y_train , epochs=5 , validation_data=(X_test , y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.6799 - loss: 0.5669 - val_accuracy: 0.8073 - val_loss: 0.4245
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8345 - loss: 0.3801 - val_accuracy: 0.8115 - val_loss: 0.4184
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8671 - loss: 0.3182 - val_accuracy: 0.8058 - val_loss: 0.4377
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8870 - loss: 0.2845 - val_accuracy: 0.7946 - val_loss: 0.4607
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9002 - loss: 0.2563 - val_accuracy: 0.7986 - val_loss: 0.4938
